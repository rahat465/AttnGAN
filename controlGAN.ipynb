# %% [markdown]
# <a href="https://colab.research.google.com/github/rahat465/AttnGAN/blob/master/controlGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mrlibw/ControlGAN.git
# Out:
# Cloning into 'ControlGAN'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 32 (delta 5), reused 18 (delta 2), pack-reused 0
# Unpacking objects: 100% (32/32), done.

# %%
# !unzip /content/drive/MyDrive/download/birds.zip -d /content/ControlGAN/data

# %%
# %cd /content/ControlGAN/data/birds
# Out:
# /content/ControlGAN/data/birds

# %%
# !tar -xf /content/drive/MyDrive/kaggledataset/CUB_200_2011.tgz

# %%
# !unzip /content/drive/MyDrive/download/bird.zip -d /content/ControlGAN/DAMSMencoders
# Out:
# Archive:  /content/drive/MyDrive/download/bird.zip
#    creating: /content/ControlGAN/DAMSMencoders/bird/
#   inflating: /content/ControlGAN/DAMSMencoders/bird/image_encoder.pth
#   inflating: /content/ControlGAN/DAMSMencoders/bird/text_encoder.pth

# %%
# !cp /content/drive/MyDrive/download/bird_ControlGAN.pth /content/ControlGAN/models

# %% [markdown]
# TEsting the model for birds dataset

# %%
# !unzip /content/ControlGAN/data/birds/text.zip -d /content/ControlGAN/data/birds
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/ControlGAN/data/birds/__MACOSX/text/159.Black_and_white_Warbler/._Black_And_White_Warbler_0135_160334.txt
#   inflating: /content/ControlGAN/data/birds/__MACOSX/text/._159.Black_and_white_Warbler
#    creating: /content/ControlGAN/data/birds/text/160.Black_throated_Blue_Warbler/
#   inflating: /content/ControlGAN/data/birds/text/160.Black_throated_Blue_Warbler/Black_Throated_Blue_Warbler_0001_161189.txt
#    creating: /content/ControlGAN/data/birds/__MACOSX/text/160.Black_throated_Blue_Warbler/
#   inflating: /content/ControlGAN/data/birds/__MACOSX/text/160.Black_throated_Blue_Warbler/._Black_Throated_Blue_Warbler_0001_161189.txt
#   inflating: /content/ControlGAN/data/birds/text/160.Black_throated_Blue_Warbler/Black_Throated_Blue_Warbler_0002_161533.txt
#   inflating: /content/ControlGAN/data/birds/__MACOSX/text/160.Black_throated_Blue_Warbler/._Black_Throated_Blue_Warbler_0002_161533.txt
# ...

# %%
# %cd /content/ControlGAN/code
# Out:
# /content/ControlGAN/code

# %%
# !python main.py --cfg cfg/eval_bird.yml --gpu 0

# %%
# !python pretrain_DAMSM.py --cfg cfg/DAMSM/bird.yml --gpu 0
# Out:
# Using config:
# {'B_VALIDATION': False,
#  'CONFIG_NAME': 'DAMSM',
#  'CUDA': True,
#  'DATASET_NAME': 'birds',
#  'DATA_DIR': '../data/birds',
#  'GAN': {'B_ATTENTION': True,
#          'B_DCGAN': False,
#          'CONDITION_DIM': 100,
#          'DF_DIM': 64,
#          'GF_DIM': 128,
#          'R_NUM': 2,
#          'Z_DIM': 100},
#  'GPU_ID': 0,
#  'RNN_TYPE': 'LSTM',
#  'TEXT': {'CAPTIONS_PER_IMAGE': 10, 'EMBEDDING_DIM': 256, 'WORDS_NUM': 18},
#  'TRAIN': {'BATCH_SIZE': 10,
#            'B_NET_D': True,
#            'DISCRIMINATOR_LR': 0.0002,
#            'ENCODER_LR': 0.002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'MAX_EPOCH': 10,
#            'NET_E': '',
#            'NET_G': '',
#            'RNN_GRAD_CLIP': 0.25,
#            'SMOOTH': {'GAMMA1': 4.0,
#                       'GAMMA2': 5.0,
#                       'GAMMA3': 10.0,
#                       'LAMBDA': 1.0},
#            'SNAPSHOT_INTERVAL': 50,
# ...

# %%
# !python main.py --cfg cfg/train_bird.yml --gpu 0
# Out:
# Using config:
# {'B_VALIDATION': False,
#  'CONFIG_NAME': 'ControlGAN',
#  'CUDA': True,
#  'DATASET_NAME': 'birds',
#  'DATA_DIR': '../data/birds',
#  'GAN': {'B_ATTENTION': True,
#          'B_DCGAN': False,
#          'CONDITION_DIM': 100,
#          'DF_DIM': 64,
#          'GF_DIM': 32,
#          'R_NUM': 2,
#          'Z_DIM': 100},
#  'GPU_ID': 0,
#  'RNN_TYPE': 'LSTM',
#  'TEXT': {'CAPTIONS_PER_IMAGE': 10, 'EMBEDDING_DIM': 256, 'WORDS_NUM': 18},
#  'TRAIN': {'BATCH_SIZE': 8,
#            'B_NET_D': True,
#            'DISCRIMINATOR_LR': 0.0002,
#            'ENCODER_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'MAX_EPOCH': 600,
#            'NET_E': '../DAMSMencoders/bird/text_encoder.pth',
#            'NET_G': '',
#            'RNN_GRAD_CLIP': 0.25,
#            'SMOOTH': {'GAMMA1': 4.0,
#                       'GAMMA2': 5.0,
#                       'GAMMA3': 10.0,
#                       'LAMBDA': 5.0},
# ...
